# %%
import youtube_dl
import os
import pandas as pd
from pydub import AudioSegment

# %%
WHITE_NOISE = "/m/0chx_"
YOUTUBE_LINK = "https://www.youtube.com/watch?v="
counter = 1

# %%
def download_audio(path, name):
    ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': name,
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'mp3',
        'preferredquality': '192'
    }],
    }
    with youtube_dl.YoutubeDL(ydl_opts) as ydl:
        ydl.download([path])

# %%
def trim_audio(path, start, end, dest):
    os.system(r'ffmpeg -i "' + path + r'" -ss '+str(start)+ ' -to ' + str(end) + ' -c copy ' + dest)
    os.system(r'rm ' + path)

# %%
# convert wav to mp3
def convert_to_wav(src, dst):                                                            
    sound = AudioSegment.from_mp3(src)
    sound.export(dst, format="wav")
    os.system(r'rm ' + src)

# %%
df = pd.read_csv("audio.csv", sep=", ", header=None, engine='python')

# %%
df.head()
# Out:
#              0      1      2                             3
# 0  --PJHxphWEs   30.0   40.0         "/m/09x0r,/t/dd00088"
# 1  --ZhevVpy1s   50.0   60.0                   "/m/012xff"
# 2  --aE2O5G5WE    0.0   10.0  "/m/03fwl,/m/04rlf,/m/09x0r"
# 3  --aO5cdqSAg   30.0   40.0       "/t/dd00003,/t/dd00005"
# 4  --aaILOrkII  200.0  210.0         "/m/032s66,/m/073cg4"

# %%
for index, row in df.iterrows():
    if row[3].find(WHITE_NOISE) != -1:
        path = "NoiseSample_" + str(counter)
        try:
            download_audio(YOUTUBE_LINK+row[0], path + "_full" + ".mp4")
            trim_audio(path + "_full" + ".mp3", int(row[1]), int(row[2]), path + ".mp3")
            convert_to_wav(path+".mp3", path+".wav")

        except Exception as e:
            print(e)
        counter += 1
# Out:
# [youtube] -ETSfElMyNc: Downloading webpage
# [youtube] -ETSfElMyNc: Downloading MPD manifest
# [dashsegments] Total fragments: 54
# [download] Destination: NoiseSample_1_full.mp4
# [download] 100% of 7.86MiB in 00:12.53MiB/s ETA 00:000106
# [ffmpeg] Destination: NoiseSample_1_full.mp3
# Deleting original file NoiseSample_1_full.mp4 (pass -k to keep)
# [youtube] -dEOa2GkXHw: Downloading webpage
# [download] Destination: NoiseSample_2_full.mp4
# [download] 100% of 2.61MiB in 00:0101MiB/s ETA 00:002
# [ffmpeg] Destination: NoiseSample_2_full.mp3
# Deleting original file NoiseSample_2_full.mp4 (pass -k to keep)
# [youtube] 0fm0oU8FO0U: Downloading webpage
# [download] Destination: NoiseSample_3_full.mp4
# [download] 100% of 1.33MiB in 00:0068MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_3_full.mp4"
# [ffmpeg] Destination: NoiseSample_3_full.mp3
# Deleting original file NoiseSample_3_full.mp4 (pass -k to keep)
# [youtube] 0uWEnGBLjXI: Downloading webpage
# [download] Destination: NoiseSample_4_full.mp4
# [download] 100% of 1.04MiB in 00:0065MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_4_full.mp4"
# [ffmpeg] Destination: NoiseSample_4_full.mp3
# Deleting original file NoiseSample_4_full.mp4 (pass -k to keep)
# [youtube] 19v5EvjdToU: Downloading webpage
# [download] Destination: NoiseSample_5_full.mp4
# [download] 100% of 1.64MiB in 00:0083MiB/s ETA 00:0001
# [ffmpeg] Destination: NoiseSample_5_full.mp3
# Deleting original file NoiseSample_5_full.mp4 (pass -k to keep)
# [youtube] 1M-zH_FQDdM: Downloading webpage
# [youtube] 1M-zH_FQDdM: Downloading MPD manifest
# [dashsegments] Total fragments: 12
# [download] Destination: NoiseSample_6_full.mp4
# [download] 100% of 1.64MiB in 00:01.69MiB/s ETA 00:00009
# [ffmpeg] Destination: NoiseSample_6_full.mp3
# Deleting original file NoiseSample_6_full.mp4 (pass -k to keep)
# [youtube] 2CvioUWZjlo: Downloading webpage
# [youtube] 2CvioUWZjlo: Downloading MPD manifest
# [dashsegments] Total fragments: 64
# [download] Destination: NoiseSample_7_full.mp4
# [download] 100% of 11.08MiB in 00:12.32MiB/s ETA 00:00007
# [ffmpeg] Destination: NoiseSample_7_full.mp3
# Deleting original file NoiseSample_7_full.mp4 (pass -k to keep)
# [youtube] 2VwH-n3jjL0: Downloading webpage
# [download] Destination: NoiseSample_8_full.mp4
# [download] 100% of 10.91MiB in 00:0176MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_8_full.mp4"
# [ffmpeg] Destination: NoiseSample_8_full.mp3
# Deleting original file NoiseSample_8_full.mp4 (pass -k to keep)
# [youtube] 2rPv0UjHwR4: Downloading webpage
# ERROR: 2rPv0UjHwR4: YouTube said: Unable to extract video data
# ERROR: 2rPv0UjHwR4: YouTube said: Unable to extract video data
# [youtube] 2wioYiUbkyM: Downloading webpage
# [download] Destination: NoiseSample_10_full.mp4
# [download] 100% of 592.53KiB in 00:0010MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_10_full.mp3
# Deleting original file NoiseSample_10_full.mp4 (pass -k to keep)
# [youtube] 4zose15iYVM: Downloading webpage
# [download] Destination: NoiseSample_11_full.mp4
# [download] 100% of 10.11MiB in 00:0184MiB/s ETA 00:00known ETA
# [ffmpeg] Destination: NoiseSample_11_full.mp3
# Deleting original file NoiseSample_11_full.mp4 (pass -k to keep)
# [youtube] 5n0xq6pE_mg: Downloading webpage
# [download] Destination: NoiseSample_12_full.mp4
# [download] 100% of 8.95MiB in 00:0166MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_12_full.mp3
# Deleting original file NoiseSample_12_full.mp4 (pass -k to keep)
# [youtube] 5pr4K4sTDE4: Downloading webpage
# [download] Destination: NoiseSample_13_full.mp4
# [download] 100% of 9.27MiB in 00:0110MiB/s ETA 00:000
# [ffmpeg] Correcting container in "NoiseSample_13_full.mp4"
# [ffmpeg] Destination: NoiseSample_13_full.mp3
# Deleting original file NoiseSample_13_full.mp4 (pass -k to keep)
# [youtube] 6mdPZ4dRYMo: Downloading webpage
# [download] Destination: NoiseSample_14_full.mp4
# [download] 100% of 1.61MiB in 00:0074MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_14_full.mp4"
# [ffmpeg] Destination: NoiseSample_14_full.mp3
# Deleting original file NoiseSample_14_full.mp4 (pass -k to keep)
# [youtube] 7enfWOAynno: Downloading webpage
# [download] Destination: NoiseSample_15_full.mp4
# [download] 100% of 4.01MiB in 00:0061MiB/s ETA 00:004
# [ffmpeg] Destination: NoiseSample_15_full.mp3
# Deleting original file NoiseSample_15_full.mp4 (pass -k to keep)
# [youtube] 8NfcSlEmXRs: Downloading webpage
# [download] Destination: NoiseSample_16_full.mp4
# [download] 100% of 1.76MiB in 00:0042MiB/s ETA 00:002
# [ffmpeg] Destination: NoiseSample_16_full.mp3
# Deleting original file NoiseSample_16_full.mp4 (pass -k to keep)
# [youtube] 9PyWiDtI0dw: Downloading webpage
# ERROR: 9PyWiDtI0dw: YouTube said: Unable to extract video data
# ERROR: 9PyWiDtI0dw: YouTube said: Unable to extract video data
# [youtube] 9tlHzTPksMI: Downloading webpage
# [youtube] 9tlHzTPksMI: Downloading MPD manifest
# [dashsegments] Total fragments: 3
# [download] Destination: NoiseSample_18_full.mp4
# [download] 100% of 225.18KiB in 00:00.11MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_18_full.mp3
# Deleting original file NoiseSample_18_full.mp4 (pass -k to keep)
# [youtube] DLIBuXMYH9g: Downloading webpage
# [download] Destination: NoiseSample_19_full.mp4
# [download] 100% of 242.93KiB in 00:0030MiB/s ETA 00:000
# [ffmpeg] Correcting container in "NoiseSample_19_full.mp4"
# [ffmpeg] Destination: NoiseSample_19_full.mp3
# Deleting original file NoiseSample_19_full.mp4 (pass -k to keep)
# [youtube] Fb1Gm9IfOe4: Downloading webpage
# ERROR: Fb1Gm9IfOe4: YouTube said: Unable to extract video data
# ERROR: Fb1Gm9IfOe4: YouTube said: Unable to extract video data
# [youtube] GtJYQg_E1cY: Downloading webpage
# [download] Destination: NoiseSample_21_full.mp4
# [download] 100% of 2.56MiB in 00:0008MiB/s ETA 00:003
# [ffmpeg] Destination: NoiseSample_21_full.mp3
# Deleting original file NoiseSample_21_full.mp4 (pass -k to keep)
# [youtube] GyhyOmsK2LE: Downloading webpage
# [download] Destination: NoiseSample_22_full.mp4
# [download] 100% of 13.89MiB in 00:0114MiB/s ETA 00:004
# [ffmpeg] Correcting container in "NoiseSample_22_full.mp4"
# [ffmpeg] Destination: NoiseSample_22_full.mp3
# Deleting original file NoiseSample_22_full.mp4 (pass -k to keep)
# [youtube] HAKA7KlwvmQ: Downloading webpage
# [download] Destination: NoiseSample_23_full.mp4
# [download] 100% of 853.47KiB in 00:0052MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_23_full.mp4"
# [ffmpeg] Destination: NoiseSample_23_full.mp3
# Deleting original file NoiseSample_23_full.mp4 (pass -k to keep)
# [youtube] J8WSfe8IAb8: Downloading webpage
# [download] Destination: NoiseSample_24_full.mp4
# [download] 100% of 4.53MiB in 00:0189MiB/s ETA 00:005
# [ffmpeg] Correcting container in "NoiseSample_24_full.mp4"
# [ffmpeg] Destination: NoiseSample_24_full.mp3
# Deleting original file NoiseSample_24_full.mp4 (pass -k to keep)
# [youtube] JZMBafpxf40: Downloading webpage
# [download] Destination: NoiseSample_25_full.mp4
# [download] 100% of 210.71KiB in 00:0067MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_25_full.mp3
# Deleting original file NoiseSample_25_full.mp4 (pass -k to keep)
# [youtube] Jy5ZMSsjqVg: Downloading webpage
# [download] Destination: NoiseSample_26_full.mp4
# [download] 100% of 8.14MiB in 00:0132MiB/s ETA 00:003
# [ffmpeg] Correcting container in "NoiseSample_26_full.mp4"
# [ffmpeg] Destination: NoiseSample_26_full.mp3
# Deleting original file NoiseSample_26_full.mp4 (pass -k to keep)
# [youtube] KF26zBFsheA: Downloading webpage
# [download] Destination: NoiseSample_27_full.mp4
# [download] 100% of 9.58MiB in 00:0120MiB/s ETA 00:001
# [ffmpeg] Destination: NoiseSample_27_full.mp3
# Deleting original file NoiseSample_27_full.mp4 (pass -k to keep)
# [youtube] KzMQOZ59_V0: Downloading webpage
# [download] Destination: NoiseSample_28_full.mp4
# [download] 100% of 3.85MiB in 00:0054MiB/s ETA 00:004
# [ffmpeg] Destination: NoiseSample_28_full.mp3
# Deleting original file NoiseSample_28_full.mp4 (pass -k to keep)
# [youtube] MH9Oj_g6xYU: Downloading webpage
# [download] Destination: NoiseSample_29_full.mp4
# [download] 100% of 1.47MiB in 00:0012MiB/s ETA 00:002
# [ffmpeg] Correcting container in "NoiseSample_29_full.mp4"
# [ffmpeg] Destination: NoiseSample_29_full.mp3
# Deleting original file NoiseSample_29_full.mp4 (pass -k to keep)
# [youtube] MIhSDMLIs_g: Downloading webpage
# [download] Destination: NoiseSample_30_full.mp4
# [download] 100% of 5.72MiB in 00:0174MiB/s ETA 00:009
# [ffmpeg] Correcting container in "NoiseSample_30_full.mp4"
# [ffmpeg] Destination: NoiseSample_30_full.mp3
# Deleting original file NoiseSample_30_full.mp4 (pass -k to keep)
# [youtube] Nnxk0BzreLU: Downloading webpage
# [download] Destination: NoiseSample_31_full.mp4
# [download] 100% of 12.71MiB in 00:0144MiB/s ETA 00:003
# [ffmpeg] Destination: NoiseSample_31_full.mp3
# Deleting original file NoiseSample_31_full.mp4 (pass -k to keep)
# [youtube] ROPkuiStRr0: Downloading webpage
# [download] Destination: NoiseSample_32_full.mp4
# [download] 100% of 262.75KiB in 00:0001MiB/s ETA 00:000
# [ffmpeg] Correcting container in "NoiseSample_32_full.mp4"
# [ffmpeg] Destination: NoiseSample_32_full.mp3
# Deleting original file NoiseSample_32_full.mp4 (pass -k to keep)
# [youtube] S6kjov9iHLs: Downloading webpage
# [download] Destination: NoiseSample_33_full.mp4
# [download] 100% of 1.08MiB in 00:0087MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_33_full.mp4"
# [ffmpeg] Destination: NoiseSample_33_full.mp3
# Deleting original file NoiseSample_33_full.mp4 (pass -k to keep)
# [youtube] SFOBjWoQkjU: Downloading webpage
# [download] Destination: NoiseSample_34_full.mp4
# [download] 100% of 556.51KiB in 00:0047MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_34_full.mp3
# Deleting original file NoiseSample_34_full.mp4 (pass -k to keep)
# [youtube] TrEo8J0j7_s: Downloading webpage
# [download] Destination: NoiseSample_35_full.mp4
# [download] 100% of 86.97KiB in 00:0077MiB/s ETA 00:000
# [ffmpeg] Correcting container in "NoiseSample_35_full.mp4"
# [ffmpeg] Destination: NoiseSample_35_full.mp3
# Deleting original file NoiseSample_35_full.mp4 (pass -k to keep)
# [youtube] TzSVnfQO36I: Downloading webpage
# [download] Destination: NoiseSample_36_full.mp4
# [download] 100% of 3.85MiB in 00:0038MiB/s ETA 00:007
# [ffmpeg] Destination: NoiseSample_36_full.mp3
# Deleting original file NoiseSample_36_full.mp4 (pass -k to keep)
# [youtube] U4ke4e8hwGc: Downloading webpage
# [download] Destination: NoiseSample_37_full.mp4
# [download] 100% of 13.89MiB in 00:0270MiB/s ETA 00:00known ETA
# [ffmpeg] Correcting container in "NoiseSample_37_full.mp4"
# [ffmpeg] Destination: NoiseSample_37_full.mp3
# Deleting original file NoiseSample_37_full.mp4 (pass -k to keep)
# [youtube] Vhtu-Xo_cbI: Downloading webpage
# [download] Destination: NoiseSample_38_full.mp4
# [download] 100% of 702.74KiB in 00:0017MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_38_full.mp3
# Deleting original file NoiseSample_38_full.mp4 (pass -k to keep)
# [youtube] XhZ9XeZNsdI: Downloading webpage
# [youtube] XhZ9XeZNsdI: Downloading MPD manifest
# [dashsegments] Total fragments: 24
# [download] Destination: NoiseSample_39_full.mp4
# [download] 100% of 3.56MiB in 00:03.26MiB/s ETA 00:00008
# [ffmpeg] Destination: NoiseSample_39_full.mp3
# Deleting original file NoiseSample_39_full.mp4 (pass -k to keep)
# [youtube] Xn9o4D_leMU: Downloading webpage
# [youtube] Xn9o4D_leMU: Downloading MPD manifest
# [dashsegments] Total fragments: 14
# [download] Destination: NoiseSample_40_full.mp4
# [download] 100% of 1.87MiB in 00:01.07MiB/s ETA 00:00004
# [ffmpeg] Correcting container in "NoiseSample_40_full.mp4"
# [ffmpeg] Destination: NoiseSample_40_full.mp3
# Deleting original file NoiseSample_40_full.mp4 (pass -k to keep)
# [youtube] YZVRuSPq67M: Downloading webpage
# [download] Destination: NoiseSample_41_full.mp4
# [download] 100% of 3.68MiB in 00:0042MiB/s ETA 00:004
# [ffmpeg] Destination: NoiseSample_41_full.mp3
# Deleting original file NoiseSample_41_full.mp4 (pass -k to keep)
# [youtube] Ya_rlzLZTOI: Downloading webpage
# [download] Destination: NoiseSample_42_full.mp4
# [download] 100% of 254.08KiB in 00:0075MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_42_full.mp3
# Deleting original file NoiseSample_42_full.mp4 (pass -k to keep)
# [youtube] aEbYdJCy9GI: Downloading webpage
# [youtube] aEbYdJCy9GI: Downloading MPD manifest
# [dashsegments] Total fragments: 21
# [download] Destination: NoiseSample_43_full.mp4
# [download] 100% of 2.99MiB in 00:02.98MiB/s ETA 00:00027
# [ffmpeg] Destination: NoiseSample_43_full.mp3
# Deleting original file NoiseSample_43_full.mp4 (pass -k to keep)
# [youtube] chB9TzdxxGk: Downloading webpage
# [download] Destination: NoiseSample_44_full.mp4
# [download] 100% of 764.13KiB in 00:0026MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_44_full.mp4"
# [ffmpeg] Destination: NoiseSample_44_full.mp3
# Deleting original file NoiseSample_44_full.mp4 (pass -k to keep)
# [youtube] dybarNq-Nmk: Downloading webpage
# [youtube] dybarNq-Nmk: Downloading MPD manifest
# [dashsegments] Total fragments: 71
# [download] Destination: NoiseSample_45_full.mp4
# [download] 100% of 10.78MiB in 00:07.75MiB/s ETA 00:00035
# [ffmpeg] Correcting container in "NoiseSample_45_full.mp4"
# [ffmpeg] Destination: NoiseSample_45_full.mp3
# Deleting original file NoiseSample_45_full.mp4 (pass -k to keep)
# [youtube] eka3CsdumkE: Downloading webpage
# [download] Destination: NoiseSample_46_full.mp4
# [download] 100% of 8.92MiB in 00:0191MiB/s ETA 00:000
# [ffmpeg] Destination: NoiseSample_46_full.mp3
# Deleting original file NoiseSample_46_full.mp4 (pass -k to keep)
# [youtube] fNp3_11a_WM: Downloading webpage
# [download] Destination: NoiseSample_47_full.mp4
# [download] 100% of 915.55KiB in 00:0037MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_47_full.mp4"
# [ffmpeg] Destination: NoiseSample_47_full.mp3
# Deleting original file NoiseSample_47_full.mp4 (pass -k to keep)
# [youtube] jXdACS6PknU: Downloading webpage
# [download] Destination: NoiseSample_48_full.mp4
# [download] 100% of 12.70MiB in 00:0200MiB/s ETA 00:002
# [ffmpeg] Destination: NoiseSample_48_full.mp3
# Deleting original file NoiseSample_48_full.mp4 (pass -k to keep)
# [youtube] jrNYJZ8L9PQ: Downloading webpage
# [download] Destination: NoiseSample_49_full.mp4
# [download] 100% of 8.23MiB in 00:0149MiB/s ETA 00:009
# [ffmpeg] Correcting container in "NoiseSample_49_full.mp4"
# [ffmpeg] Destination: NoiseSample_49_full.mp3
# Deleting original file NoiseSample_49_full.mp4 (pass -k to keep)
# [youtube] kYrJadZmjm0: Downloading webpage
# [download] Destination: NoiseSample_50_full.mp4
# [download] 100% of 12.70MiB in 00:0130MiB/s ETA 00:003
# [ffmpeg] Destination: NoiseSample_50_full.mp3
# Deleting original file NoiseSample_50_full.mp4 (pass -k to keep)
# [youtube] ncEthcdxCUg: Downloading webpage
# [youtube] ncEthcdxCUg: Downloading MPD manifest
# [dashsegments] Total fragments: 12
# [download] Destination: NoiseSample_51_full.mp4
# [download] 100% of 1.60MiB in 00:01.06MiB/s ETA 00:0001:13
# [ffmpeg] Correcting container in "NoiseSample_51_full.mp4"
# [ffmpeg] Destination: NoiseSample_51_full.mp3
# Deleting original file NoiseSample_51_full.mp4 (pass -k to keep)
# [youtube] ov0Fe829K7s: Downloading webpage
# ERROR: ov0Fe829K7s: YouTube said: Unable to extract video data
# ERROR: ov0Fe829K7s: YouTube said: Unable to extract video data
# [youtube] qWtGOflwoLU: Downloading webpage
# [download] Destination: NoiseSample_53_full.mp4
# [download] 100% of 5.73MiB in 00:0037MiB/s ETA 00:007
# [ffmpeg] Destination: NoiseSample_53_full.mp3
# Deleting original file NoiseSample_53_full.mp4 (pass -k to keep)
# [youtube] qkT1a6TECYM: Downloading webpage
# [download] Destination: NoiseSample_54_full.mp4
# [download] 100% of 2.35MiB in 00:0051MiB/s ETA 00:003
# [ffmpeg] Correcting container in "NoiseSample_54_full.mp4"
# [ffmpeg] Destination: NoiseSample_54_full.mp3
# Deleting original file NoiseSample_54_full.mp4 (pass -k to keep)
# [youtube] sckl7bvI0Uc: Downloading webpage
# ERROR: sckl7bvI0Uc: YouTube said: Unable to extract video data
# ERROR: sckl7bvI0Uc: YouTube said: Unable to extract video data
# [youtube] tFqQhDcFqaw: Downloading webpage
# [youtube] tFqQhDcFqaw: Downloading MPD manifest
# [dashsegments] Total fragments: 9
# [download] Destination: NoiseSample_56_full.mp4
# [download] 100% of 1.08MiB in 00:01.06MiB/s ETA 00:000001
# [ffmpeg] Destination: NoiseSample_56_full.mp3
# Deleting original file NoiseSample_56_full.mp4 (pass -k to keep)
# [youtube] uRIzEtwt8MY: Downloading webpage
# ERROR: uRIzEtwt8MY: YouTube said: Unable to extract video data
# ERROR: uRIzEtwt8MY: YouTube said: Unable to extract video data
# [youtube] veaAVn2NHAk: Downloading webpage
# [download] Destination: NoiseSample_58_full.mp4
# [download] 100% of 8.99MiB in 00:0137MiB/s ETA 00:001
# [ffmpeg] Correcting container in "NoiseSample_58_full.mp4"
# [ffmpeg] Destination: NoiseSample_58_full.mp3
# Deleting original file NoiseSample_58_full.mp4 (pass -k to keep)
# [youtube] yiSeCcyJuxE: Downloading webpage
# [download] Destination: NoiseSample_59_full.mp4
# [download] 100% of 4.87MiB in 00:0051MiB/s ETA 00:008
# [ffmpeg] Destination: NoiseSample_59_full.mp3
# Deleting original file NoiseSample_59_full.mp4 (pass -k to keep)
# [youtube] zhQGK0mnHPQ: Downloading webpage
# [download] Destination: NoiseSample_60_full.mp4
# [download] 100% of 9.46MiB in 00:0108MiB/s ETA 00:000
# [ffmpeg] Correcting container in "NoiseSample_60_full.mp4"
# [ffmpeg] Destination: NoiseSample_60_full.mp3
# Deleting original file NoiseSample_60_full.mp4 (pass -k to keep)
